# %% [markdown]
# <a href="https://colab.research.google.com/github/zlw1225/MPLC_CUDA/blob/main/colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/zlw1225/MPLC_CUDA.git

# %%
import os
os.getcwd()
path="/content/MPLC_CUDA"
os.chdir(path)
os.getcwd()

# %%
# !python MPLC_CUDA2.py --iterations 2 --calc_perf_every_it 1

# %% [markdown]
# function ClickConnect() {
#   var connectButton = document.querySelector("colab-toolbar-button#connect");
#   if(connectButton != null) {
#     console.log("Working");
#     connectButton.click();
#   }
# }
# setInterval(ClickConnect, 60000);

# %%
# import sys
# sys.path.append('/content/MPLC_CUDA')  # 或者在本地环境中使用实际路径
# %matplotlib inline
exec(open('MPLC_CUDA2.py', encoding='utf-8').read())
exec(open('MPLC_CUDA2_printandplot.py', encoding='utf-8').read())
# Out:
# [MPLC2] Using device: cuda
# [MPLC2] GPU: NVIDIA GeForce RTX 3060, capability=(8, 6), torch_cuda=12.1
# [MPLC2] 运行元信息已保存到 results/run_meta.json
# iteration 10 : loc. fidelity = 91.1 , crosstalk = 18.16 , efficiency = 12.13
# iteration 20 : loc. fidelity = 97.96 , crosstalk = 5.01 , efficiency = 10.38
# iteration 30 : loc. fidelity = 98.3 , crosstalk = 2.68 , efficiency = 13.45
# iteration 40 : loc. fidelity = 98.21 , crosstalk = 1.74 , efficiency = 19.01
# iteration 50 : loc. fidelity = 98.17 , crosstalk = 1.55 , efficiency = 22.84
# iteration 60 : loc. fidelity = 98.15 , crosstalk = 1.46 , efficiency = 26.45
# iteration 70 : loc. fidelity = 98.14 , crosstalk = 1.39 , efficiency = 29.38
# iteration 80 : loc. fidelity = 98.15 , crosstalk = 1.36 , efficiency = 31.99
# iteration 90 : loc. fidelity = 98.15 , crosstalk = 1.33 , efficiency = 34.22
# iteration 100 : loc. fidelity = 98.15 , crosstalk = 1.32 , efficiency = 36.18
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib
plt.figure(figsize=(6, 5))
plt.imshow(Masks[4].detach().cpu().numpy(), cmap='RdBu_r', origin='lower', vmin=-math.pi, vmax=math.pi)
plt.title('Mask 4 (phase, radians)')
plt.colorbar(label='Phase (radians)')

plt.show()
# Out:
# Using matplotlib backend: qtagg

# %%
# 显示被裁剪的 Mask4（原始大小）
plt.figure(figsize=(6, 5))
plt.imshow(Masks[4].detach().cpu().numpy(), cmap='RdBu_r', origin='lower', vmin=-math.pi, vmax=math.pi)
plt.title('Mask 4 (cropped, phase, radians)')
plt.colorbar(label='Phase (radians)')
plt.axis('off')
plt.show()

# 显示 pad 后的 Mask4（宽域大小）
plt.figure(figsize=(8, 7))
plt.imshow(Masks_wide[4].detach().cpu().numpy(), cmap='RdBu_r', origin='lower', vmin=-math.pi, vmax=math.pi)
plt.title('Mask 4 (padded, phase, radians)')
plt.colorbar(label='Phase (radians)')
plt.axis('off')
plt.show()

# %%
import torch

smask = torch.load('results/masks_opt_and_crop.pt')
# 显示优化后的第4个mask（smask['Masks_opt'][4]）
plt.figure(figsize=(6, 5))
plt.imshow(smask['Masks_opt'][4].detach().cpu().numpy(), cmap='RdBu_r', origin='lower', vmin=-math.pi, vmax=math.pi)
plt.title('smask["Masks_opt"][4] (phase, radians)')
plt.colorbar(label='Phase (radians)')
plt.show()

# 显示裁剪后的第4个mask（smask['Masks_crop'][4]）
plt.figure(figsize=(6, 5))
plt.imshow(smask['Masks_crop'][4].detach().cpu().numpy(), cmap='RdBu_r', origin='lower', vmin=-math.pi, vmax=math.pi)
plt.title('smask["Masks_crop"][4] (phase, radians)')
plt.colorbar(label='Phase (radians)')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10228\4002622935.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
