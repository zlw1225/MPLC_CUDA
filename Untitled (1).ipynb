# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
# %cd /
# !rm -rf MPLC_CUDA
# !git clone https://github.com/zlw1225/MPLC_CUDA.git
# %cd /MPLC_CUDA
# Out:
# /
# Cloning into 'MPLC_CUDA'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 91 (delta 13), reused 21 (delta 9), pack-reused 64 (from 1)
# Receiving objects: 100% (91/91), 103.03 MiB | 10.62 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /MPLC_CUDA

# %%
import math 
val1 = 2 * math.pi / 7
val0 =  val1 
# !python MPLC_CUDA2.py --delta_theta_1 {val1} --delta_theta_0 {val0}
# Out:
# [MPLC2] Using device: cuda
# [MPLC2] GPU: NVIDIA GeForce RTX 2080 Ti, capability=(7, 5), torch_cuda=12.8
# [MPLC2] 运行元信息已保存到 results/run_meta.json
# Figure(1500x1000)
# iteration 10: loc. fidelity = 84.8, crosstalk = 25.88, efficiency = 16.79
# iteration 20: loc. fidelity = 70.1, crosstalk = 53.46, efficiency = 11.1
# iteration 30: loc. fidelity = 91.29, crosstalk = 23.26, efficiency = 16.47
# iteration 40: loc. fidelity = 87.97, crosstalk = 32.7, efficiency = 20.2
# iteration 50: loc. fidelity = 91.58, crosstalk = 30.01, efficiency = 18.55
# iteration 60: loc. fidelity = 89.67, crosstalk = 32.55, efficiency = 25.7
# iteration 70: loc. fidelity = 91.87, crosstalk = 31.13, efficiency = 21.52
# iteration 80: loc. fidelity = 90.23, crosstalk = 30.88, efficiency = 27.52
# iteration 90: loc. fidelity = 93.31, crosstalk = 28.31, efficiency = 22.73
# iteration 100: loc. fidelity = 92.06, crosstalk = 27.15, efficiency = 28.41
# iteration 110: loc. fidelity = 94.22, crosstalk = 24.11, efficiency = 23.78
# iteration 120: loc. fidelity = 94.0, crosstalk = 22.28, efficiency = 29.29
# iteration 130: loc. fidelity = 95.63, crosstalk = 19.09, efficiency = 24.65
# iteration 140: loc. fidelity = 95.56, crosstalk = 17.61, efficiency = 30.45
# iteration 150: loc. fidelity = 96.44, crosstalk = 14.64, efficiency = 25.62
# iteration 160: loc. fidelity = 96.77, crosstalk = 12.53, efficiency = 31.91
# iteration 170: loc. fidelity = 97.37, crosstalk = 9.61, efficiency = 27.41
# iteration 180: loc. fidelity = 97.8, crosstalk = 7.76, efficiency = 34.08
# iteration 190: loc. fidelity = 98.21, crosstalk = 5.26, efficiency = 30.86
# iteration 200: loc. fidelity = 98.57, crosstalk = 4.13, efficiency = 37.23
# iteration 210: loc. fidelity = 98.72, crosstalk = 2.98, efficiency = 36.1
# iteration 220: loc. fidelity = 98.98, crosstalk = 2.52, efficiency = 40.49
# iteration 230: loc. fidelity = 99.04, crosstalk = 2.29, efficiency = 40.78
# iteration 240: loc. fidelity = 99.13, crosstalk = 2.23, efficiency = 42.12
# iteration 250: loc. fidelity = 99.14, crosstalk = 2.2, efficiency = 42.31
# iteration 260: loc. fidelity = 99.15, crosstalk = 2.19, efficiency = 42.5
# iteration 270: loc. fidelity = 99.16, crosstalk = 2.2, efficiency = 42.6
# Final performance (avg over λ): loc. fidelity = 99.158 , crosstalk = 2.197 , efficiency = 42.596
# λ=1.530 µm -> fidelity=98.463, crosstalk=2.684, efficiency=35.732
# λ=1.550 µm -> fidelity=99.291, crosstalk=2.143, efficiency=43.158
# λ=1.570 µm -> fidelity=99.474, crosstalk=1.977, efficiency=46.796
# λ=1.590 µm -> fidelity=99.504, crosstalk=1.933, efficiency=47.167
# λ=1.610 µm -> fidelity=99.351, crosstalk=2.043, efficiency=44.241
# λ=1.625 µm -> fidelity=98.866, crosstalk=2.401, efficiency=38.484
# [Save] Full-size phase masks saved to results/masks_full.pt

# %%
# !python MPLC_CUDA2_printandplot.py

#--nx_crop 512 --ny_crop 1024
# Out:
# Wavelengths (μm): ['1.530', '1.550', '1.570', '1.590', '1.610', '1.625']
# [Full]    IL (dB): ['-4.514', '-3.650', '-3.306', '-3.270', '-3.552', '-4.173']
# [Cropped] IL (dB): ['-5.271', '-4.369', '-4.028', '-4.006', '-4.325', '-4.989']
# [Full]    XTs (dB): ['-25.987', '-29.529', '-31.389', '-30.816', '-28.179', '-25.370']
# [Cropped] XTs (dB): ['-20.683', '-22.028', '-22.341', '-22.007', '-21.159', '-19.856']
# [Full]    MDL (dB): ['1.892', '1.244', '1.192', '1.201', '1.340', '1.775']
# [Cropped] MDL (dB): ['2.778', '2.286', '2.265', '2.316', '2.468', '2.907']
# [Full]    fidelity : ['98.463', '99.291', '99.474', '99.504', '99.351', '98.866']
# [Cropped] fidelity : ['97.010', '98.258', '98.584', '98.632', '98.382', '97.560']
# [Full]    crosstalk: ['2.684', '2.143', '1.977', '1.933', '2.043', '2.401']
# [Cropped] crosstalk: ['7.282', '5.477', '5.035', '5.043', '5.573', '7.034']
# [Full]    efficiency: ['35.732', '43.158', '46.796', '47.167', '44.241', '38.484']
# [Cropped] efficiency: ['29.943', '36.492', '39.360', '39.519', '36.758', '31.734']
# ΔIL (crop-full)  (dB): ['-0.757', '-0.718', '-0.721', '-0.736', '-0.774', '-0.816']
# ΔXTs (crop-full) (dB): ['5.304', '7.501', '9.049', '8.808', '7.021', '5.514']
# Mean ΔIL=-0.754 dB, Mean ΔXTs=7.199 dB
# [Save] Cropped phase masks saved to results/masks_cropped.pt
